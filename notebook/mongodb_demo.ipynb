# %% [markdown]
# MongoDB Connection String

# %%
'''mongodb+srv://jhaa0761_db_user:
RULSL3dBxjKtkex1@cluster0.au2jiuo.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'''
# Out:
# 'mongodb+srv://jhaa0761_db_user:\nRULSL3dBxjKtkex1@cluster0.au2jiuo.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
